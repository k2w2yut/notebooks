# %%
import pandas as pd
import sklearn as sk
import numpy as np
from itertools import groupby
from pythainlp.tokenize import word_tokenize
from pythainlp.corpus import thai_stopwords

# %%
train_data = pd.read_csv('data/w_review_train.csv',names=['text','score'],sep=';')
train_data.head()
# Out:
#                                                 text  score
# 0  ร้านอาหารใหญ่มากกกกกกก \nเลี้ยวเข้ามาเจอห้องน้...      3
# 1  อาหารที่นี่เป็นอาหารจีนแคะที่หากินยากในบ้านเรา...      4
# 2  ปอเปี๊ยะสด ทุกวันนี้รู้สึกว่าหากินยาก (ร้านที่...      3
# 3  รัานคัพเค้กในเมืองไทยมีไม่มาก หลายๆคนอาจจะสงสั...      5
# 4  อร่อย!!! เดินผ่านDigital gatewayทุกวัน ไม่ยักร...      5

# %%
train_data['text'][0]
# Out:
# 'ร้านอาหารใหญ่มากกกกกกก \nเลี้ยวเข้ามาเจอห้องน้ำก่อนเลย เออแปลกดี \nห้องทานหลักๆอยู่ชั้น 2 มีกาแฟ น้ำผึ้ง ซึ่งก็แค่เอาน้ำผึ้งมาราด แพงเวอร์ อย่าสั่งเลย \nลาบไข่ต้ม ไข่มันคาวอะ เลยไม่ประทับใจเท่าไหร่\nทอดมันหัวปลีกรอบอร่อยต้องเบิ้ล \nพะแนงห่อไข่อร่อยดี เห้ยแต่ราคา 150บาทมันเกินไปนะ รับไม่ไหวว\nเลิกกินแล้วมีขนมหวานให้กินฟรีเล็กน้อย )ขนมไทย) \n\nคงไม่ไปซ้ำ แพงเกิน '

# %%
t0 = word_tokenize(train_data['text'][0],engine='deepcut')
t0
# Out:
# ['ร้าน',
#  'อาหาร',
#  'ใหญ่',
#  'มาก',
#  'กกกกกก',
#  ' \n',
#  'เลี้ยว',
#  'เข้า',
#  'มา',
#  'เจอ',
#  'ห้องน้ำ',
#  'ก่อน',
#  'เลย',
#  ' ',
#  'เออแปลก',
#  'ดี',
#  ' \n',
#  'ห้องทาน',
#  'หลัก',
#  'ๆ',
#  'อยู่',
#  'ชั้น',
#  ' ',
#  '2',
#  ' ',
#  'มี',
#  'กาแฟ',
#  ' ',
#  'น้ำผึ้ง',
#  ' ',
#  'ซึ่ง',
#  'ก็',
#  'แค่',
#  'เอา',
#  'น้ำผึ้ง',
#  'มา',
#  'ราด',
#  ' แพงเวอร์',
#  ' ',
#  'อย่า',
#  'สั่ง',
#  'เลย',
#  ' \n',
#  'ลาบ',
#  'ไข่',
#  'ต้ม',
#  ' ',
#  'ไข่',
#  'มัน',
#  'คาว',
#  'อะ',
#  ' ',
#  'เลย',
#  'ไม่',
#  'ประทับใจ',
#  'เท่า',
#  'ไหร่\n',
#  'ทอด',
#  'มัน',
#  'หัว',
#  'ปลีก',
#  'รอบ',
#  'อร่อย',
#  'ต้อง',
#  'เบิ้ล',
#  ' \n',
#  'พะแนง',
#  'ห่อ',
#  'ไข่',
#  'อร่อย',
#  'ดี',
#  ' ',
#  'เห้ยแต่',
#  'ราคา',
#  ' ',
#  '150',
#  'บาท',
#  'มัน',
#  'เกิน',
#  'ไป',
#  'นะ',
#  ' ',
#  'รับ',
#  'ไม่',
#  'ไหวว\n',
#  'เลิก',
#  'กิน',
#  'แล้ว',
#  'มี',
#  'ขนม',
#  'หวาน',
#  'ให้',
#  'กิน',
#  'ฟรี',
#  'เล็กน้อย',
#  ' ',
#  ')',
#  'ขนม',
#  'ไทย',
#  ')',
#  ' \n\n',
#  'คง',
#  'ไม่',
#  'ไป',
#  'ซ้ำ',
#  ' ',
#  'แพงเกิน',
#  ' ']

# %%
stop_word = thai_stopwords()
stop_word
# Out:
# frozenset({'พอแล้ว',
#            'ทีเดียว',
#            'ตลอดทั่วถึง',
#            'พวกโน้น',
#            'ต่าง',
#            'ละ',
#            'นี่แน่ะ',
#            'เป็นอาทิ',
#            'นี่',
#            'ตลอดทั้ง',
#            'ยิ่งจน',
#            'ค่ะ',
#            'ไหนๆ',
#            'แต่จะ',
#            'ด้วยที่',
#            'แต่ถ้า',
#            'จวนเจียน',
#            'อย่างๆ',
#            'จัดตั้ง',
#            'ต่างหาก',
#            'หนึ่ง',
#            'ส่วน',
#            'ย่อย',
#            'นับแต่',
#            'พวกฉัน',
#            'ไกล',
#            'กระผม',
#            'แห่งไหน',
#            'โตๆ',
#            'ฉัน',
#            'ภายภาค',
#            'แห่งนี้',
#            'ทั้งที',
#            'ซึ่ง',
#            'ฯ',
#            'รือว่า',
#            'ยัง',
#            'เชื่อมั่น',
#            'จนเมื่อ',
#            'นั่นเอง',
#            'สมัยก่อน',
#            'ล้วนแต่',
#            'เพียงแค่',
#            'คือ',
#            'เสียนี่',
#            'เช่น',
#            'แต่อย่างใด',
#            'เหล่า',
#            'พบ',
#            'เคย',
#            'ชาว',
#            'ครั้งหลัง',
#            'ตั้ง',
#            'ส่วนนั้น',
#            'ขอ',
#            'มุ่งเน้น',
#            'เถอะ',
#            'จวบ',
#            'กลุ่มก้อน',
#            'เสียยิ่งนัก',
#            'หาใช่',
#            'ด้วยเหมือนกัน',
#            'แต่',
#            'นี่ไง',
#            'ทุกอย่าง',
#            'กลุ่มๆ',
#            'เมื่อวาน',
#            'ยาว',
#            'จวบจน',
#            'อย่างไรก็ได้',
#            'จนกระทั่ง',
#            'ได้มา',
#            'กัน',
#            'จัดให้',
#            'ส่วนที่',
#            'นำมา',
#            'รวมทั้ง',
#            'สั้นๆ',
#            'ครานี้',
#            'ทีๆ',
#            'ซะก่อน',
#            'ทุกหน',
#            'เสร็จ',
#            'บางที่',
#            'ถึงเมื่อใด',
#            'พอสม',
#            'เพียงเพราะ',
#            'นางสาว',
#            'ภายใต้',
#            'เป็นต้นไป',
#            'ทีเถอะ',
#            'เสียด้วย',
#            'บางครา',
#            'เป็นการ',
#            'พวกคุณ',
#            'หรือ',
#            'พวกนู้น',
#            'พอๆ',
#            'จวนจะ',
#            'สูงๆ',
#            'ทัน',
#            'บางๆ',
#            'ฯล',
#            'ซึ่งกันและกัน',
#            'นับ',
#            'บ่อยๆ',
#            'ไม่',
#            'คล้ายกันกับ',
#            'มอง',
#            'ให้มา',
#            'ได้แก่',
#            'เมื่อใด',
#            'ทำให้',
#            'พอตัว',
#            'ตน',
#            'เห็นจะ',
#            'ทําให้',
#            'แก',
#            'เนี่ย',
#            'ๆ',
#            'ในเมื่อ',
#            'สมัย',
#            'แค่นั้น',
#            'ผู้',
#            'เผื่อที่',
#            'ที่ละ',
#            'นํา',
#            'กับ',
#            'เหตุผล',
#            'ให้แด่',
#            'ระหว่าง',
#            'ก็ตาม',
#            'กันดีไหม',
#            'ง่ายๆ',
#            'นาน',
#            'แต่ไร',
#            'ช่วงนั้น',
#            'เพียงแต่',
#            'ที่จริง',
#            'ตรง',
#            'ยิ่งใหญ่',
#            'แห่ง',
#            'ที่ได้',
#            'ทั้งเป็น',
#            'ทันทีทันใด',
#            'ค่อนข้างจะ',
#            'มิ',
#            'ยืนยัน',
#            'จด',
#            'คล้าย',
#            'จังๆ',
#            'เช่นดังที่',
#            'ถ้าจะ',
#            'ร่วม',
#            'ข้างเคียง',
#            'บาง',
#            'ที่',
#            'เป็นเพียงว่า',
#            'ปรับ',
#            'เสียก่อน',
#            'ก่อนหน้า',
#            'รับ',
#            'พร้อม',
#            'ฝ่ายใด',
#            'ให้ดี',
#            'เป็นเพียง',
#            'หมดกัน',
#            'เริ่ม',
#            'วันนี้',
#            'พวกแก',
#            'หมดสิ้น',
#            'ร่วมด้วย',
#            'ราย',
#            'อย่างใด',
#            'ยาก',
#            'ก็ตามแต่',
#            'ส่วนน้อย',
#            'จนขณะนี้',
#            'ตามแต่',
#            'เสมือนกับ',
#            'ควร',
#            'ทั้ง',
#            'ฉะนั้น',
#            'อย่างไรเสีย',
#            'ครา',
#            'บัดนั้น',
#            'ใกล้ๆ',
#            'ครั้งหนึ่ง',
#            'มุ่ง',
#            'อย่างนี้',
#            'ขั้น',
#            'จวบกับ',
#            'จริง',
#            'มัน',
#            'ล้วนจน',
#            'ส่วนมาก',
#            'ช่วงถัดไป',
#            'กล่าว',
#            'ข้างต้น',
#            'ทุกวันนี้',
#            'ดั่งกับว่า',
#            'หน',
#            'ตามๆ',
#            'เสียจนถึง',
#            'ก็',
#            'ทั้งที่',
#            'ช่วงหน้า',
#            'ช่วงหลัง',
#            'เขา',
#            'เราๆ',
#            'ทั้งนั้นด้วย',
#            'เห็นว่า',
#            'เสียแล้ว',
#            'คงอยู่',
#            'เช่นนั้นเอง',
#            'เสียนั่นเอง',
#            'เพียงเพื่อ',
#            'เร็วๆ',
#            'เพื่อ',
#            'ส่วนใหญ่',
#            'เสร็จกัน',
#            'ให้ไป',
#            'แต่ต้อง',
#            'มิฉะนั้น',
#            'อื่น',
#            'โต',
#            'แม้กระทั่ง',
#            'ทำไม',
#            'รึว่า',
#            'ครั้งก่อน',
#            'เสีย',
#            'เสมือนว่า',
#            'ค่อยๆ',
#            'นิด',
#            'ครั้งละ',
#            'ทั้งตัว',
#            'พวกนั้น',
#            'แสดงว่า',
#            'ซึ่งกัน',
#            'คราวนี้',
#            'นับแต่นี้',
#            'ถ้า',
#            'แล้วกัน',
#            'น่ะ',
#            'ขณะใดๆ',
#            'เกินๆ',
#            'คล้ายกับว่า',
#            'แม้ว่า',
#            'ที่ว่า',
#            'แท้',
#            'นี่เอง',
#            'ทั้งหมด',
#            'หรือเปล่า',
#            'จนบัดนี้',
#            'ซึ่งๆ',
#            'นับตั้งแต่',
#            'ตลอดทั่วทั้ง',
#            'เช่นเดียวกัน',
#            'รวมๆ',
#            'ในที่',
#            'ทั้งนี้',
#            'เท่าไร',
#            'อันเนื่องมาจาก',
#            'จึงจะ',
#            'ช้าๆ',
#            'พอ',
#            'แม้',
#            'อย่าง',
#            'ยังแต่',
#            'ส่วนดี',
#            'ส่วนด้อย',
#            'ทำไร',
#            'ขณะนั้น',
#            'ยิ่งจะ',
#            'ใหม่',
#            'อย่างละ',
#            'น้อย',
#            'ได้',
#            'ซะ',
#            'เท่ากับ',
#            'ออก',
#            'ช่วย',
#            'เป็นอันๆ',
#            'ครานั้น',
#            'ก็แล้วแต่',
#            'ฝ่าย',
#            'นั้นๆ',
#            'แค่เพียง',
#            'เมื่อไหร่',
#            'สูง',
#            'ไม่ใช่',
#            'จำพวก',
#            'แต่ไหน',
#            'ถูกๆ',
#            'เสียจนกระทั่ง',
#            'กันและกัน',
#            'ทั้งมวล',
#            'นอก',
#            'คล้ายกัน',
#            'ด้วยเหตุที่',
#            'เหลือเกิน',
#            'เป็นอันมาก',
#            'ให้แก่',
#            'มั้ย',
#            'คล้ายว่า',
#            'คุณๆ',
#            'เฉพาะ',
#            'เลย',
#            'บ้าง',
#            'กำหนด',
#            'ครั้งใด',
#            'ขณะใด',
#            'ที่ไหน',
#            'ใช้',
#            'นะ',
#            'ไกลๆ',
#            'ยังงั้น',
#            'บางครั้ง',
#            'คิดว่า',
#            'ดั่งเคย',
#            'เผื่อว่า',
#            'พร้อมเพียง',
#            'เขียน',
#            'ร่วมกัน',
#            'ทาง',
#            'หนอ',
#            'มา',
#            'นับจากนี้',
#            'สิ่งนี้',
#            'หลาย',
#            'อาจ',
#            'ด้วยว่า',
#            'หน่อย',
#            'ยิ่งกว่า',
#            'นอกนั้น',
#            'กันเถอะ',
#            'เช่นที่',
#            'อดีต',
#            'เล่าว่า',
#            'เฉกเช่น',
#            'ทุกทาง',
#            'แค่นี้',
#            'ได้แต่',
#            'แต่ทว่า',
#            'นอกจากว่า',
#            'ทุกแห่ง',
#            'เมื่อเย็น',
#            'ทุกเมื่อ',
#            'หากแม้นว่า',
#            'พอเหมาะ',
#            'วัน',
#            'ซึ่งก็',
#            'ถึงแม้จะ',
#            'ตนฯ',
#            'เอ็ง',
#            'เมื่อคืน',
#            'ทุกคน',
#            'ครั้งคราว',
#            'ใหม่ๆ',
#            'ไป',
#            'เหตุไร',
#            'เกี่ยวข้อง',
#            'ต่างก็',
#            'รวดเร็ว',
#            'ใกล้',
#            'ใคร',
#            'นิดหน่อย',
#            'อย่างนั้น',
#            'แต่ละ',
#            'ได้รับ',
#            'แค่ไหน',
#            'ทีละ',
#            'แต่ก็',
#            'คราวหนึ่ง',
#            'เกี่ยวกับ',
#            'ด้วยเช่นกัน',
#            'สําหรับ',
#            'เช่นก่อน',
#            'เมื่อครั้ง',
#            'กระทำ',
#            'ต้อง',
#            'คล้ายกับ',
#            'อีก',
#            'คราที่',
#            'เฉยๆ',
#            'ตลอดทั่ว',
#            'นอกเหนือจาก',
#            'เรียบ',
#            'ตลอดศก',
#            'ที่นี้',
#            'หารือ',
#            'เพิ่งจะ',
#            'ข้าง',
#            'เฉย',
#            'เข้า',
#            'พอกัน',
#            'เยอะ',
#            'ตลอดมา',
#            '\ufeffๆ',
#            'สูงส่ง',
#            'นั้น',
#            'ครบครัน',
#            'อัน',
#            'ช่วงๆ',
#            'สบาย',
#            'เปิดเผย',
#            'ใน',
#            'เปลี่ยนแปลง',
#            'ตลอดปี',
#            'มี',
#            'คราวใด',
#            'เช่นใด',
#            'ข้างบน',
#            'จริงจัง',
#            'ทั้งสิ้น',
#            'ทั้งหลาย',
#            'นี้',
#            'ที่ซึ่ง',
#            'ครั้งครา',
#            'พวกมัน',
#            'พา',
#            'จน',
#            'เท่าไหร่',
#            'ยกให้',
#            'ให้',
#            'ถึงจะ',
#            'นอกจากที่',
#            'แต่เดิม',
#            'เช่นที่ว่า',
#            'ยิ่ง',
#            'ใช่',
#            'ตาม',
#            'บางคราว',
#            'แต่ก่อน',
#            'เท่าที่',
#            'ใครๆ',
#            'จัด',
#            'มีแต่',
#            'เมื่อก่อน',
#            'เช่นดัง',
#            'ผู้ใด',
#            'พวกมึง',
#            'เท่านี้',
#            'สิ่งนั้น',
#            'ดั่งกับ',
#            'กล่าวคือ',
#            'ไฉน',
#            'ถือ',
#            'ทว่า',
#            'แก่',
#            'พอจะ',
#            'เชื่อ',
#            'ส่วนใด',
#            'สมัยนี้',
#            'แต่ที่',
#            'คราวหลัง',
#            'ตลอดเวลา',
#            'อะไร',
#            'พวกที่',
#            'นอกจากนี้',
#            'กระนั้น',
#            'ค่อนมาทาง',
#            'พร้อมด้วย',
#            'มิใช่',
#            'ใดๆ',
#            'มากกว่า',
#            'ภาย',
#            'ที่สุด',
#            'จริงๆจังๆ',
#            'ขึ้น',
#            'บัดดล',
#            'เรื่อย',
#            'นิดๆ',
#            'น้อยกว่า',
#            'บัดนี้',
#            'ใหญ่ๆ',
#            'หรือไร',
#            'เป็นต้น',
#            'ครั้งนี้',
#            'ด้วยกัน',
#            'รวม',
#            'จะ',
#            'น่าจะ',
#            'แห่งใด',
#            'คง',
#            'เยอะแยะ',
#            'มั้ยเนี่ย',
#            'ยิ่งขึ้นไป',
#            'อย่างเดียว',
#            'ตั้งแต่',
#            'พอที',
#            'กันไหม',
#            'เพื่อที่',
#            'กันดีกว่า',
#            'ส่ง',
#            'เกือบ',
#            'กลับ',
#            'สืบเนื่อง',
#            'ทั้งคน',
#            'สิ่งใด',
#            'วันใด',
#            'ยืนยาว',
#            'เป็นเพื่อ',
#            'เมื่อวันวาน',
#            'เหตุ',
#            'ทุกคราว',
#            'ยาวนาน',
#            'ไง',
#            'จำ',
#            'นั้นไว',
#            'น่า',
#            'เรื่อยๆ',
#            'เมื่อคราว',
#            'คะ',
#            'ข้าฯ',
#            'เมื่อคราวที่',
#            'สุดๆ',
#            'กันเอง',
#            'จึง',
#            'ภาค',
#            'ถึงแม้',
#            'อันที่',
#            'เก็บ',
#            'มักจะ',
#            'แต่นั้น',
#            'รวด',
#            'ใต้',
#            'จำเป็น',
#            'จ้ะ',
#            'ทุก',
#            'ครบถ้วน',
#            'เอง',
#            'ถึงบัดนั้น',
#            'นับจากนั้น',
#            'แค่ว่า',
#            'ฯลฯ',
#            'ทั้งปวง',
#            'เป็นต้นมา',
#            'กว้างขวาง',
#            'จัง',
#            'ครั้งกระนั้น',
#            'ถึงแม้ว่า',
#            'เกี่ยวๆ',
#            'เกี่ยวเนื่อง',
#            'ภายหลัง',
#            'อื่นๆ',
#            'ณ',
#            'จวน',
#            'ครัน',
#            'ต่อกัน',
#            'บอก',
#            'ไม่ค่อย',
#            'สิ้นกาลนาน',
#            'แต่เมื่อ',
#            'ช่วงนี้',
#            'พึง',
#            'นี่นา',
#            'แค่',
#            'ไม่ว่า',
#            'อย่างดี',
#            'นี้เอง',
#            'ถึงแก่',
#            'เห็นแก่',
#            'ค่อยไปทาง',
#            'นี้แหล่',
#            'เผื่อจะ',
#            'กว้าง',
#            'ด้วยประการฉะนี้',
#            'พบว่า',
#            'เพิ่มเติม',
#            'เผื่อ',
#            'ขณะที่',
#            'เพียง',
#            'ถือว่า',
#            'เกี่ยวกัน',
#            'ระยะ',
#            'ถ้าหาก',
#            'เกิด',
#            'ประการ',
#            'สูงกว่า',
#            'แสดง',
#            'ก็ดี',
#            'เท่ากัน',
#            'จาก',
#            'ยิ่งขึ้น',
#            'เช่นดังว่า',
#            'เถิด',
#            'ลง',
#            'ซะจนกระทั่ง',
#            'การ',
#            'ดัง',
#            'ถึงบัดนี้',
#            'ต่อ',
#            'ก่อน',
#            'นู่น',
#            'ยังงี้',
#            'อนึ่ง',
#            'แล้วแต่',
#            'เน้น',
#            'บางกว่า',
#            'รือ',
#            'ความ',
#            'คราวหน้า',
#            'ใคร่',
#            'คราไหน',
#            'ไม่เป็นไร',
#            'จัดงาน',
#            'ทุกวัน',
#            'สูงสุด',
#            'ดั่งเก่า',
#            'หรือไง',
#            'เพียงไร',
#            'ก็ตามที',
#            'พวก',
#            'นั่น',
#            'กำลัง',
#            'เป็นเพราะ',
#            'เมื่อนั้น',
#            'ถึงอย่างไร',
#            'ใหญ่',
#            'และ',
#            'หาความ',
#            'ทันใดนั้น',
#            'เช่นดังก่อน',
#            'ตามที่',
#            'ภายใน',
#            'เอา',
#            'ช้านาน',
#            'อันละ',
#            'ก็คือ',
#            'เมื่อ',
#            'รวมถึง',
#            'เพื่อที่จะ',
#            'ยืนนาน',
#            'ภายหน้า',
#            'ช่วงท้าย',
#            'เล็กน้อย',
#            'เสร็จสิ้น',
#            'ยังไง',
#            'พร้อมที่',
#            'รวมกัน',
#            'ขณะเดียวกัน',
#            'อาจจะ',
#            'เยอะๆ',
#            'มั้ยนะ',
#            'ภายนอก',
#            'หากว่า',
#            'นั่นเป็น',
#            'ในระหว่าง',
#            'สมัยโน้น',
#            'พร้อมทั้ง',
#            'ตรงๆ',
#            'อย่างมาก',
#            'ไป่',
#            'เห็น',
#            'ย่อม',
#            'ตลอดระยะเวลา',
#            'ที่นั้น',
#            'พอดี',
#            'กลุ่ม',
#            'ปัจจุบัน',
#            'มั้ยนั่น',
#            'บางแห่ง',
#            'ผิดๆ',
#            'เช่นที่เคย',
#            'อันได้แก่',
#            'ผ่านๆ',
#            'แต่เพียง',
#            'ข้าพเจ้า',
#            'เสียนี่กระไร',
#            'มึง',
#            'ทั้งนั้น',
#            'พอสมควร',
#            'พวกกัน',
#            'สิ่งไหน',
#            'แก้ไข',
#            'หรือไม่',
#            'กว้างๆ',
#            'ที่ๆ',
#            'ถูกต้อง',
#            'นั่นแหละ',
#            'ที่แล้ว',
#            'ปรากฏว่า',
#            'คราวละ',
#            'หรือยัง',
#            'ปรากฏ',
#            'จ้า',
#            'ฉะนี้',
#            'อย่างไร',
#            'เมื่อครั้งก่อน',
#            'ครั้งๆ',
#            'ดังเคย',
#            'มากมาย',
#            'ร่วมมือ',
#            'ด้วยเหตุว่า',
#            'จับ',
#            'นานๆ',
#            'เมื่อเช้า',
#            'ไว้',
#            'สู่',
#            'หลัง',
#            'ยิ่งแล้ว',
#            'ขณะ',
#            'จากนั้น',
#            'ตลอดกาล',
#            'แค่จะ',
#            'ก่อนๆ',
#            'ยืนยง',
#            'ตลอดถึง',
#            'อย่างโน้น',
#            'พร้อมกัน',
#            'นำ',
#            'จรด',
#            'เป็น',
#            'บ่อยครั้ง',
#            'หนอย',
#            'ทันที',
#            'ดังกล่าว',
#            'ยิ่งเมื่อ',
#            'พอที่',
#            'เมื่อนี้',
#            'ขวางๆ',
#            'เช่นเดียวกับ',
#            'นอกเหนือ',
#            'เดียว',
#            'ถึงเมื่อไร',
#            'ต่างๆ',
#            'เหล่านี้',
#            'ครั้งนั้น',
#            'ที่แท้',
#            'เชื่อว่า',
#            'ทํา',
#            'เพียงพอ',
#            'เต็มๆ',
#            'พวกกู',
#            'พร้อมกับ',
#            'ที',
#            'ผ่าน',
#            'ยังคง',
#            'เสียยิ่ง',
#            'คิด',
#            'เหล่านั้น',
#            'ถูก',
#            'เท่านั้น',
#            'จึงเป็น',
#            'แห่งนั้น',
#            'ที่แห่งนั้น',
#            'อันใด',
#            'คราวก่อน',
#            'นอกจาก',
#            'นาง',
#            'ช่วงที่',
#            'นับแต่นั้น',
#            'อันจะ',
#            'จะได้',
#            'เพิ่ง',
#            'ตลอดจน',
#            'ซึ่งได้แก่',
#            'ดังกับว่า',
#            'เป็นเพราะว่า',
#            'เล็กๆ',
#            'เป็นที',
#            'บางที',
#            'อยู่',
#            'สิ่ง',
#            'สมัยนั้น',
#            'คราวที่',
#            'จนทั่ว',
#            'ตนเอง',
#            'เชื่อถือ',
#            'เช่นไร',
#            'อย่างไหน',
#            'จนแม้',
#            'เหตุนี้',
#            'เป็นด้วย',
#            'อาจเป็น',
#            'เพื่อว่า',
#            'อย่างที่',
#            'ช่วงก่อน',
#            'เนี่ยเอง',
#            'พวกนี้',
#            'เป็นอัน',
#            'บ่อยกว่า',
#            'ก็ได้',
#            'แบบ',
#            'เท่าใด',
#            'เพื่อให้',
#            'เช่นกัน',
#            'ครบ',
#            'แล้ว',
#            'เพิ่ม',
#            'เพียงใด',
#            'แยะ',
#            'เกือบจะ',
#            'มิได้',
#            'พยายาม',
#            'คราใด',
#            'ช่วงระหว่าง',
#            'จากนี้ไป',
#            'ทีใด',
#            'ยังจะ',
#            'จ๊ะ',
#            'มองว่า',
#            'พวกเขา',
#            'เปลี่ยน',
#            'เรียก',
#            'บัดเดี๋ยวนี้',
#            'คราวโน้น',
#            'รึ',
#            'คราหนึ่ง',
#            'เหลือ',
#            'คราวๆ',
#            'จัดการ',
#            'หากแม้น',
#            'ได้ที่',
#            'เนื่องจาก',
#            'เข้าใจ',
#            'แล้วเสร็จ',
#            'พึ่ง',
#            'อย่างน้อย',
#            'เปิด',
#            'ใช่ไหม',
#            'เป็นที่สุด',
#            'เป็นอันว่า',
#            'ปฏิบัติ',
#            'ภายภาคหน้า',
#            'ช้า',
#            'กระทั่ง',
#            'จ๋า',
#            'ครับ',
#            'ยก',
#            'นักๆ',
#            'จัดแจง',
#            'ทุกอัน',
#            'เมื่อไร',
#            'แห่งโน้น',
#            'คราวไหน',
#            'ไร',
#            'วันไหน',
#            'ประการใด',
#            'ประการฉะนี้',
#            'เช่นดังเก่า',
#            'ทั่ว',
#            'เสร็จสมบูรณ์',
#            'ส่วนเกิน',
#            'อันที่จะ',
#            'อย่างเช่น',
#            'พื้นๆ',
#            'ยิ่งนัก',
#            'บน',
#            'ด้าน',
#            'นำพา',
#            'บอกว่า',
#            'คงจะ',
#            'ตลอดไป',
#            'นี่แหละ',
#            'แรก',
#            'ซะจน',
#            'เป็นแต่เพียง',
#            'ทั้งนั้นเพราะ',
#            'สำคัญ',
#            'รับรอง',
#            'ทุกๆ',
#            'เมื่อคราวก่อน',
#            'ทุกครั้ง',
#            'นอกจากนั้น',
#            'แท้จริง',
#            'ล้วน',
#            'พูด',
#            'ล่าสุด',
#            'ครั้งที่',
#            'เสร็จแล้ว',
#            'ค่อน',
#            'ผิด',
#            'ก็จะ',
#            'อาจเป็นด้วย',
#            'ด้วยเหตุนั้น',
#            'ทรง',
#            'สั้น',
#            'ช่วง',
#            'ด้วยเหตุนี้',
#            'ยอม',
#            'ทั้งๆ',
#            'หาก',
#            'เช่นเคย',
#            'เสียนั่น',
#            'นั่นไง',
#            'ดังเก่า',
#            'ครั้งหลังสุด',
#            'จนตลอด',
#            'ก่อนหน้านี้',
#            'ของ',
#            'หลังจาก',
#            'ระยะๆ',
#            'ก็ต่อเมื่อ',
#            'ตลอด',
#            'ตลอดวัน',
#            'พอเพียง',
#            'คุณ',
#            'เพราะ',
#            'หากแม้',
#            'ถึงเมื่อ',
#            'อันไหน',
#            'เหตุนั้น',
#            'เพราะว่า',
#            'จัดทำ',
#            'บางขณะ',
#            'จนแม้น',
#            'เกิน',
#            'จากนี้',
#            'ก็แค่',
#            'ง่าย',
#            'ช่วงต่อไป',
#            'ประการหนึ่ง',
#            'จนถึง',
#            'ที่ใด',
#            'เคยๆ',
#            'คราว',
#            'ครั้งไหน',
#            'ประสบ',
#            'จนกว่า',
#            'เพราะฉะนั้น',
#            'แต่ว่า',
#            'ทุกสิ่ง',
#            'นู้น',
#            'มุ่งหมาย',
#            'เช่นนั้น',
#            'ใหญ่โต',
#            'ข้า',
#            'เพียงไหน',
#            'สิ้น',
#            'มั้ยล่ะ',
#            'กว่า',
#            'ช่วงแรก',
#            'นัก',
#            'ที่แท้จริง',
#            'ทุกตัว',
#            'ทุกที',
#            'มั๊ย',
#            'แหละ',
#            'จู่ๆ',
#            'ผล',
#            'เช่นนี้',
#            'จง',
#            'ตลอดกาลนาน',
#            'เป็นดัง',
#            'ขณะหนึ่ง',
#            'ไม่ค่อยเป็น',
#            'ประมาณ',
#            'นาย',
#            'ค่อย',
#            'ด้วย',
#            'ค่อนข้าง',
#            'เต็มไปด้วย',
#            'ไม่ค่อยจะ',
#            'ข้างๆ',
#            'ใคร่จะ',
#            'รวมด้วย',
#            'เสียจน',
#            'ตามด้วย',
#            'ยังโง้น',
#            'มันๆ',
#            'สุด',
#            'เรา',
#            'แยะๆ',
#            'ทำๆ',
#            'ไหน',
#            'เล็ก',
#            'ซะจนถึง',
#            'ขณะนี้',
#            'เกือบๆ',
#            'เร็ว',
#            'จัดหา',
#            'เป็นๆ',
#            'ทุกที่',
#            'แม้แต่',
#            'ทุกชิ้น',
#            'เท่า',
#            'เห็นควร',
#            'แม้นว่า',
#            'คราวนั้น',
#            'เช่นเมื่อ',
#            'ขวาง',
#            'เธอ',
#            'น้อยๆ',
#            'เป็นที่',
#            'ถึง',
#            'ภาคฯ',
#            'พวกเธอ',
#            'ยอมรับ',
#            'นับแต่ที่',
#            'อย่างยิ่ง',
#            'พวกท่าน',
#            'มัก',
#            'วันนั้น',
#            'ดังกับ',
#            'สามารถ',
#            'อันที่จริง',
#            'อยาก',
#            'ทุกครา',
#            ...})

# %%
t0_cleaned = []
escape_word = ['\n','',' ',')','(']
for word in t0:
    word = word.strip().replace('\n','')
    if word not in stop_word and word not in escape_word:
        t0_cleaned.append(word)

# %%
print('original:', len(t0))
print('remove stop word:', len(t0_cleaned))
# Out:
# original: 108
# remove stop word: 55

# %%
def tokenize_word(text):
    words_ori = word_tokenize(text,engine='deepcut')
    words_cleaned = []
    escape_word = ['\n','',' ',')','(']
    stop_word = thai_stopwords()
    for word in words_ori:
        word = word.strip().replace('\n','')
        if word not in stop_word and word not in escape_word:
            words_cleaned.append(word)
    return words_cleaned

# %%
train_data = train_data[0:50]
train_data['token'] = train_data['text'].apply(tokenize_word)

# %%
train_data.head()
# Out:
#                                                 text  score  \
# 0  ร้านอาหารใหญ่มากกกกกกก \nเลี้ยวเข้ามาเจอห้องน้...      3
# 1  อาหารที่นี่เป็นอาหารจีนแคะที่หากินยากในบ้านเรา...      4
# 2  ปอเปี๊ยะสด ทุกวันนี้รู้สึกว่าหากินยาก (ร้านที่...      3
# 3  รัานคัพเค้กในเมืองไทยมีไม่มาก หลายๆคนอาจจะสงสั...      5
# 4  อร่อย!!! เดินผ่านDigital gatewayทุกวัน ไม่ยักร...      5
#
#                                                token
# 0  [ร้าน, อาหาร, กกกกกก, เลี้ยว, เจอ, ห้องน้ำ, เอ...
# 1  [อาหาร, อาหาร, จีน, แคะ, หากิน, บ้าน, ตัว, ร้า...
# 2  [ปอเปี๊ยะ, สด, รู้สึก, หา, กิน, ร้าน, ขาย, ปอเ...
# 3  [รัานคัพ, เค้ก, เมืองไทย, คน, สงสัย, คัพเค้ก, ...
# 4  [อร่อย, !, !, !, เดิน, Digital, gateway, ยัก, ...

# %%
vocab_w = [item for sublist in train_data.token for item in sublist]
vocab_df = pd.DataFrame({'word':vocab_w})
vocab_n = vocab_df['word'].value_counts()
vocab = vocab_s[vocab_s > 1]
vocab_list = ['_'] + list(vocab.keys())
vocab_size = len(vocab_list)
print('vocab size:',vocab_size)
print('vocab list:',vocab_list[0:10])
# Out:
# vocab size: 643
# vocab list: ['_', 'ร้าน', 'กิน', 'อาหาร', 'คน', 'ดี', '"', 'เนื้อ', 'ทาน', 'อร่อย']

# %%
# [vocab_list.index(word) if word in vocab_list else 0 for word in train_data.token[0]]
vocab_onehot = []
for word in train_data.token[0]:
    if word in vocab_list:
        vocab_onehot.append(vocab_list.index(word))
    else:
        vocab_onehot.append(0)

# %%
def one_hot_word(words):
    return [vocab_list.index(word) if word in vocab_list else 0 for word in train_data.token[0]]
# Out:
#   File "<ipython-input-149-471dad336cd1>", line 2
#     for words in train_data.token:
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-4631a223f3f2> in <module>
# ----> 1 one_hot = [one_hot(t,100) for t in train_data.token]
#
# <ipython-input-97-4631a223f3f2> in <listcomp>(.0)
# ----> 1 one_hot = [one_hot(t,100) for t in train_data.token]
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/text.py in one_hot(text, n, filters, lower, split)
#      88                          filters=filters,
#      89                          lower=lower,
# ---> 90                          split=split)
#      91
#      92
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/text.py in hashing_trick(text, n, hash_function, filters, lower, split)
#     133                                 filters=filters,
#     134                                 lower=lower,
# --> 135                                 split=split)
#     136     return [(hash_function(w) % (n - 1) + 1) for w in seq]
#     137
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/text.py in text_to_word_sequence(text, filters, lower, split)
#      41     """
#      42     if lower:
# ---> 43         text = text.lower()
#      44
#      45     if sys.version_info < (3,):
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
max_length = train_data.text.map(len).max()

# %%
model = Sequential()
model.add(Embedding(vocab_size, 8, input_length=max_length))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-243da358e565> in <module>
#       1 model = Sequential()
# ----> 2 model.add(Embedding(vocab_size, 8, input_length=max_length))
#       3 model.add(Flatten())
#       4 model.add(Dense(1, activation='sigmoid'))
#
# NameError: name 'vocab_size' is not defined
